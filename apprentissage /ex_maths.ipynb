# %% [markdown]
# <a href="https://colab.research.google.com/github/neohack22/ebw3nt/blob/main/apprentissage%20/ex_maths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Installation et configuration de l’environnement

# %%
# !pip install keras keras-hub --upgrade -q

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %% [markdown]
# ### Exploration du dataset MNIST
#
# Chargez le jeu de données MNIST depuis Keras.
#
# Affichez :
# - La forme (shape) des images d’entraînement
# - Le nombre d’étiquettes d’entraînement
# - Quelques valeurs des étiquettes
# - La forme des images de test
# - Le nombre d’étiquettes de test
#
# Interprétez ces résultats.

# %% [markdown]
# ### Construction d’un premier réseau de neurones dense
#
# Construisez un modèle `Sequential` composé :
# - D’une couche Dense de 512 neurones avec activation ReLU
# - D’une couche Dense de 10 neurones avec activation Softmax
#
# Compilez le modèle avec :
# - Optimizer : Adam
# - Loss : sparse_categorical_crossentropy
# - Métrique : accuracy

# %% [markdown]
# ### Entraînement et évaluation du modèle
#
# Entraînez le modèle pendant 5 epochs avec un batch size de 128.
#
# Ensuite :
# - Faites des prédictions sur les 10 premières images de test
# - Identifiez la classe prédite pour la première image
# - Comparez avec la vraie étiquette
# - Évaluez le modèle sur l’ensemble de test et affichez l’accuracy

# %% [markdown]
# ### Représentation des données

# %% [markdown]
# ### Manipulation des tenseurs avec NumPy
#
# Créez des exemples de :
# - Scalaire (rang 0)
# - Vecteur (rang 1)
# - Matrice (rang 2)
# - Tenseur de rang 3
#
# Pour chacun :
# - Affichez sa dimension (`ndim`)
# - Expliquez ce que signifie son rang

# %% [markdown]
# ### Attributs des tenseurs MNIST
#
# À partir du dataset MNIST :
#
# Affichez :
# - Le nombre de dimensions des images
# - Leur forme
# - Leur type de données (dtype)
#
# Affichez une image avec matplotlib et indiquez son label.

# %% [markdown]
# ### Manipulation et découpage de tenseurs
#
# Effectuez différents sous-échantillonnages (slicing) sur les images MNIST :
#
# - Sélectionnez un sous-ensemble d’images
# - Extrayez une portion spécifique des images (ex: coin inférieur droit)
# - Modifiez les dimensions de découpage
#
# Expliquez l’effet de chaque slicing sur la forme du tenseur.

# %% [markdown]
# ### Comprendre la notion de batch
#
# Montrez comment extraire des lots (batches) successifs de 128 images depuis les données d’entraînement.
#
# Expliquez :
# - Ce qu’est un batch
# - Pourquoi on utilise des batches en deep learning

# %%
batch = train_images[:128]

# %%
batch = train_images[128:256]

# %%
n = 3
batch = train_images[128 * n : 128 * (n + 1)]

# %% [markdown]
# ### Opérations sur les tenseurs

# %% [markdown]
# ### Implémentation naïve d’opérations élémentaires
#
# Implémentez manuellement :
# - Une fonction ReLU
# - Une addition élément par élément entre deux matrices
#
# Comparez les performances avec les opérations vectorisées NumPy.
# Expliquez pourquoi NumPy est plus rapide.

# %%
def naive_relu(x):
    assert len(x.shape) == 2
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] = max(x[i, j], 0)
    return x

# %%
def naive_add(x, y):
    assert len(x.shape) == 2
    assert x.shape == y.shape
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[i, j]
    return x

# %%
import time

x = np.random.random((20, 100))
y = np.random.random((20, 100))

t0 = time.time()
for _ in range(1000):
    z = x + y
    z = np.maximum(z, 0.0)
print("Took: {0:.2f} s".format(time.time() - t0))

# %%
t0 = time.time()
for _ in range(1000):
    z = naive_add(x, y)
    z = naive_relu(z)
print("Took: {0:.2f} s".format(time.time() - t0))

# %% [markdown]
# ### Comprendre le broadcasting
#
# Ajoutez un vecteur à une matrice :
# - Implémentez une version naïve avec des boucles
# - Utilisez ensuite le broadcasting NumPy
#
# Expliquez ce qu’est le broadcasting et pourquoi il est utile.

# %%
import numpy as np

X = np.random.random((32, 10))
y = np.random.random((10,))

# %%
y = np.expand_dims(y, axis=0)

# %%
Y = np.tile(y, (32, 1))

# %%
def naive_add_matrix_and_vector(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[j]
    return x

# %%
import numpy as np

x = np.random.random((64, 3, 32, 10))
y = np.random.random((32, 10))
z = np.maximum(x, y)

# %% [markdown]
# ### Implémentation du produit matriciel
#
# Implémentez :
# - Produit scalaire entre deux vecteurs
# - Produit matrice-vecteur
# - Produit matrice-matrice
#
# Comparez avec `np.matmul` ou l’opérateur `@`.
# Expliquez l’interprétation géométrique du produit matriciel.

# %%
x = np.random.random((32,))
y = np.random.random((32,))

z = np.matmul(x, y)
z = x @ y

# %%
def naive_vector_product(x, y):
    assert len(x.shape) == 1
    assert len(y.shape) == 1
    assert x.shape[0] == y.shape[0]
    z = 0.0
    for i in range(x.shape[0]):
        z += x[i] * y[i]
    return z

# %%
def naive_matrix_vector_product(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            z[i] += x[i, j] * y[j]
    return z

# %%
def naive_matrix_vector_product(x, y):
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        z[i] = naive_vector_product(x[i, :], y)
    return z

# %%
def naive_matrix_product(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 2
    assert x.shape[1] == y.shape[0]
    z = np.zeros((x.shape[0], y.shape[1]))
    for i in range(x.shape[0]):
        for j in range(y.shape[1]):
            row_x = x[i, :]
            column_y = y[:, j]
            z[i, j] = naive_vector_product(row_x, column_y)
    return z

# %% [markdown]
# ### Exercice – Reshape et transpose
#
# 1. Transformez une matrice (3,2) en (6,1).
# 2. Transformez-la ensuite en (2,3).
# 3. Créez une matrice (300,20) et transposez-la.
# 4. Expliquez ce que fait la transposition.

# %% [markdown]
# ### Optimisation et gradient

# %% [markdown]
# ## Implémenter une couche Dense manuellement
#
# 1. Créez une classe représentant une couche Dense.
# 2. Initialisez une matrice de poids et un biais.
# 3. Implémentez la propagation avant (produit matriciel + biais + activation).

# %%
import keras
from keras import ops

class NaiveDense:
    def __init__(self, input_size, output_size, activation=None):
        self.activation = activation
        self.W = keras.Variable(
            shape=(input_size, output_size), initializer="uniform"
        )
        self.b = keras.Variable(shape=(output_size,), initializer="zeros")

    def __call__(self, inputs):
        x = ops.matmul(inputs, self.W)
        x = x + self.b
        if self.activation is not None:
            x = self.activation(x)
        return x

    @property
    def weights(self):
        return [self.W, self.b]

# %% [markdown]
# ## Implémenter un modèle séquentiel
#
# 1. Créez une classe permettant d’enchaîner plusieurs couches.
# 2. Implémentez l’appel successif des couches.
# 3. Récupérez la liste complète des poids du modèle.

# %%
class NaiveSequential:
    def __init__(self, layers):
        self.layers = layers

    def __call__(self, inputs):
        x = inputs
        for layer in self.layers:
            x = layer(x)
        return x

    @property
    def weights(self):
        weights = []
        for layer in self.layers:
            weights += layer.weights
        return weights

# %%
model = NaiveSequential(
    [
        NaiveDense(input_size=28 * 28, output_size=512, activation=ops.relu),
        NaiveDense(input_size=512, output_size=10, activation=ops.softmax),
    ]
)
assert len(model.weights) == 4

# %% [markdown]
# ## Implémenter un générateur de batchs
#
# 1. Créez une classe permettant de parcourir les données par mini-batchs.
# 2. Implémentez une méthode next() renvoyant images et labels.

# %%
import math

class BatchGenerator:
    def __init__(self, images, labels, batch_size=128):
        assert len(images) == len(labels)
        self.index = 0
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.num_batches = math.ceil(len(images) / batch_size)

    def next(self):
        images = self.images[self.index : self.index + self.batch_size]
        labels = self.labels[self.index : self.index + self.batch_size]
        self.index += self.batch_size
        return images, labels

# %%
learning_rate = 1e-3

def update_weights(gradients, weights):
    for g, w in zip(gradients, weights):
        w.assign(w - g * learning_rate)

# %%
from keras import optimizers

optimizer = optimizers.SGD(learning_rate=1e-3)

def update_weights(gradients, weights):
    optimizer.apply_gradients(zip(gradients, weights))

# %% [markdown]
# ## Implémenter une étape d’entraînement
#
# 1. Écrivez une fonction réalisant :
#    - propagation avant
#    - calcul de la perte
#    - calcul du gradient
#    - mise à jour des poids
# 2. Utilisez GradientTape pour le calcul automatique des gradients.

# %%
# %%backend tensorflow
# import tensorflow as tf
#
# x = tf.zeros(shape=())
# with tf.GradientTape() as tape:
#     y = 2 * x + 3
# grad_of_y_wrt_x = tape.gradient(y, x)

# %%
# %%backend tensorflow
# def one_training_step(model, images_batch, labels_batch):
#     with tf.GradientTape() as tape:
#         predictions = model(images_batch)
#         loss = ops.sparse_categorical_crossentropy(labels_batch, predictions)
#         average_loss = ops.mean(loss)
#     gradients = tape.gradient(average_loss, model.weights)
#     update_weights(gradients, model.weights)
#     return average_loss

# %% [markdown]
# ## Implémenter la boucle d’entraînement complète
#
# 1. Implémentez une fonction fit().
# 2. Parcourez les epochs.
# 3. Parcourez les batchs.
# 4. Affichez périodiquement la valeur de la perte.

# %%
# %%backend tensorflow
# def fit(model, images, labels, epochs, batch_size=128):
#     for epoch_counter in range(epochs):
#         print(f"Epoch {epoch_counter}")
#         batch_generator = BatchGenerator(images, labels)
#         for batch_counter in range(batch_generator.num_batches):
#             images_batch, labels_batch = batch_generator.next()
#             loss = one_training_step(model, images_batch, labels_batch)
#             if batch_counter % 100 == 0:
#                 print(f"loss at batch {batch_counter}: {loss:.2f}")

# %%
# %%backend tensorflow
# from keras.datasets import mnist
#
# (train_images, train_labels), (test_images, test_labels) = mnist.load_data()
#
# train_images = train_images.reshape((60000, 28 * 28))
# train_images = train_images.astype("float32") / 255
# test_images = test_images.reshape((10000, 28 * 28))
# test_images = test_images.astype("float32") / 255
#
# fit(model, train_images, train_labels, epochs=10, batch_size=128)

# %% [markdown]
# ## Évaluer le modèle entraîné
#
# 1. Effectuez des prédictions sur le jeu de test.
# 2. Déterminez les classes prédites.
# 3. Calculez l’accuracy moyenne.
